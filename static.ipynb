# %%
import requests
from bs4 import BeautifulSoup
import csv
import time
import re

class PTTPost:
    def __init__(self, title, link, date, push_count, content=""):
        self.title = title
        self.link = link
        self.date = date
        self.push_count = push_count
        self.content = content

    def to_dict(self):
        return {
            "推文數": self.push_count,
            "標題": self.title,
            "連結": self.link,
            "日期": self.date,
            "內文": self.content
        }

        
class PTTSpider:
    BASE_URL = "https://www.ptt.cc"
    
    def __init__(self, board, max_pages=5):
        self.board = board
        self.max_pages = max_pages
        self.session = requests.Session()
        self.session.cookies.set('over18', '1')  # PTT 18歲驗證
        self.posts = []

    def _fetch_page(self, url):
        print(f" Fetching: {url}")
        try:
            # 設定 headers 模擬瀏覽器（避免被擋）
            headers = {
                "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"
            }

            # 發送 GET 請求（帶入 cookie + headers）
            res = self.session.get(url, headers=headers, timeout=10)

            # 若非成功狀態碼（200 OK），印錯誤並略過
            if res.status_code != 200:
                print(f" 抓取失敗：HTTP {res.status_code} - {url}")
                print("狀態碼：", res.status_code)
                print("回傳頁面前 300 字：", res.text[:300])
                return None

            # 設定編碼，避免亂碼
            res.encoding = 'utf-8'

            # 回傳 BeautifulSoup 物件，供後續解析
            return BeautifulSoup(res.text, "html.parser")

        except requests.RequestException as e:
            # 捕捉網路錯誤，例如連線逾時、DNS 錯誤等
            print(f" 請求錯誤：{e}")
            return None



    def _parse_posts(self, soup, keyword_filter=None):
        # 取得文章列表區塊（每篇文章都是 div.r-ent）
        entries = soup.select("div.r-ent")

        for entry in entries:
            # 取得文章標題與連結元素
            title_tag = entry.select_one("div.title a")
            push_tag = entry.select_one("div.nrec")  # 推文數區塊
            date_tag = entry.select_one("div.date")  # 發文日期

            # 如果文章被刪（沒有 a 標籤），就跳過
            if not title_tag:
                continue

            title = title_tag.text.strip()

            # 跳過公告文
            if "[公告]" in title:
                continue

            link = self.BASE_URL + title_tag['href']  # 組合完整文章連結
            date = date_tag.text.strip()  # 發文日期
            push_text = push_tag.text.strip() if push_tag else "0"  # 推文數字串（如 爆、X1、15）

            # 特殊推文處理
            if push_text == "爆":
                push_count = 100
            elif re.match(r'X\d+', push_text):  # 負推文，例如 X1 → -1
                push_count = -int(push_text[1:])
            else:
                try:
                    push_count = int(push_text)  # 正常推文數
                except:
                    push_count = 0  # 無法解析時預設為 0

            # 抓取內文主文（排除推文）
            content = self._fetch_article_content(link)

            # 若有設定關鍵字，需篩選是否包含（標題＋內文）
            if keyword_filter:
                if not any(keyword.lower() in (title + content).lower() for keyword in keyword_filter):
                    continue  # 若不包含關鍵字則跳過

            # 將符合條件的文章轉為 PTTPost 並存入列表
            post = PTTPost(title, link, date, push_count, content)
            self.posts.append(post)

    def _get_next_page_url(self, soup):
        btns = soup.select("div.btn-group-paging a")
        for btn in btns:
            if "上頁" in btn.text:
                return self.BASE_URL + btn["href"]
        return None
    
    # 主爬蟲邏輯：連續抓多頁文章
    def crawl(self, keyword_filter=None):
        url = f"{self.BASE_URL}/bbs/{self.board}/index.html"
        for _ in range(self.max_pages):
            # 抓取當前頁面的 HTML 內容並轉成 BeautifulSoup 物件
            soup = self._fetch_page(url)    
            # 解析這一頁的所有文章（依據關鍵字過濾）
            self._parse_posts(soup, keyword_filter) 
            # 找到下一頁的 URL 
            url = self._get_next_page_url(soup)
            if not url:
                break
        #time.sleep(1)


    def save_to_csv(self, filename):
        with open(filename, mode='w', newline='', encoding='utf-8') as file:
            writer = csv.DictWriter(file, fieldnames=["推文數", "標題", "連結", "日期", "內文"])
            writer.writeheader()
            for post in self.posts:
                writer.writerow(post.to_dict())
        print(f" CSV 檔案已儲存：{filename}")

        
    def _fetch_article_content(self, url):
        try:
            soup = self._fetch_page(url)
            main_content = soup.select_one("#main-content")
            if not main_content:
                return ""

            # Step 1：找出「發信站」在哪個 <span class="f2">
            cut_node = None
            for span in main_content.find_all("span", class_="f2"):
                if "發信站" in span.text:
                    cut_node = span
                    break
            # if url == "https://www.ptt.cc/bbs/Lifeismoney/M.1735838860.A.6F3.html":
            #     print(main_content)
            
            # Step 2：kill div 移除文章頭的作者/時間資訊區塊
            for tag in main_content.find_all(["div"], class_=["article-metaline", "article-metaline-right"]):
                tag.decompose()
                
            
            # if url == "https://www.ptt.cc/bbs/Lifeismoney/M.1735838860.A.6F3.html":
            #     print("\n\nafter\n\n")
            #     print(main_content)
                
            # Step 3：only get 發信站 previous text
            text_lines = []
            # .contents 只抓「最外層的直接子節點」
            for content in main_content.descendants:
                # 停在發信站
                if content == cut_node:
                    break
                # 處理純文字
                elif isinstance(content, str):
                    line = content.strip()
                    if line:
                        text_lines.append(line)

            return "\n".join(text_lines)

        except Exception as e:
            print(f"⚠️ 無法讀取文章：{url}，錯誤：{e}")
            return ""

# %%
if __name__ == "__main__":
    #keywords = ["LINE", "蝦皮", "pChome", "優惠"]
    keywords = ["LINE"]
    spider = PTTSpider("Lifeismoney", max_pages=5)
    try:
        spider.crawl(keyword_filter=keywords)
    except Exception as e:
        print(f"❌ 程式錯誤：{e}")
        exit(1)
    spider.save_to_csv("static.csv")
# Out:
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/index.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1744377914.A.7F1.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1744387246.A.135.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1744389532.A.A0F.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1744389682.A.879.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1744399107.A.0EC.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1744402075.A.8BB.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1744403665.A.116.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1744415834.A.A1A.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1744417653.A.67B.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1744426820.A.981.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1744429854.A.C96.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1744429921.A.8AC.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1744434866.A.28B.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1744448128.A.421.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1744457106.A.F4A.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1744458042.A.7B8.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1744461104.A.0AE.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1744474055.A.6B0.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1744512708.A.840.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1744517146.A.271.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1735838860.A.6F3.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1741089866.A.59A.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1741089842.A.A0D.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/index3999.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1744252423.A.E0B.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1744253903.A.9E8.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1744275799.A.969.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1744278317.A.7CF.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1744296860.A.7C5.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1744297066.A.C3B.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1744312984.A.366.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1744342340.A.F15.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1744343238.A.FD2.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1744343725.A.0B6.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1744347416.A.99A.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1744347906.A.619.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1744349044.A.C97.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1744350937.A.9E3.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1744352859.A.E10.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1744366780.A.EA0.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1744368118.A.CDB.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1744369641.A.E15.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1744374109.A.18E.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1744374195.A.6FC.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/index3998.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1744115330.A.F26.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1744130869.A.D65.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1744161231.A.706.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1744165555.A.611.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1744170818.A.E66.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1744178451.A.0C6.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1744178604.A.D07.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1744179550.A.B2C.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1744180855.A.20F.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1744187071.A.CFD.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1744203359.A.DAB.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1744207492.A.F83.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1744208479.A.016.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1744214506.A.A5E.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1744215948.A.671.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1744216195.A.899.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1744219361.A.661.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1744221772.A.91C.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1744242897.A.62A.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1744243382.A.F69.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/index3997.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1743991104.A.9FB.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1743998819.A.3EC.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1743999353.A.F7B.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1744002584.A.497.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1744004316.A.DC4.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1744005022.A.E86.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1744011170.A.F28.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1744015867.A.51B.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1744022304.A.FE2.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1744022608.A.CD1.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1744024933.A.5DF.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1744035871.A.997.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1744041267.A.716.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1744042732.A.9D7.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1744045510.A.3FE.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1744078152.A.230.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1744078153.A.00B.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1744079505.A.CEC.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1744083544.A.D7E.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1744112351.A.1C5.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/index3996.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1743705714.A.CF2.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1743720029.A.ACA.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1743723043.A.7A6.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1743733092.A.7FF.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1743735760.A.B47.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1743753223.A.414.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1743756727.A.FD3.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1743765886.A.5C4.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1743786366.A.2F6.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1743817238.A.9D6.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1743860280.A.F3C.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1743871295.A.305.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1743904982.A.070.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1743906155.A.EAB.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1743912415.A.A7E.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1743916735.A.53F.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1743930713.A.6FC.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1743930905.A.E6E.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1743961554.A.CD4.html
#  Fetching: https://www.ptt.cc/bbs/Lifeismoney/M.1743984600.A.E89.html
#  CSV 檔案已儲存：static.csv

# %%
import pandas as pd
df = pd.read_csv('static.csv', encoding="utf-8")  
# 顯示前 3 筆資料
print(df.head(10))
# Out:
#    推文數                                     標題  \
# 0   72            [情報] LINE購物驚喜紅包 滿$199元回饋30元
# 1    4              line禮物 折9元，最低1元換麥香（飲料-分眾）
# 2    9  Re: [情報] LINE MOBILE吃到飽232元、輕量40元 中華線
# 3    6  Re: [情報] LINE MOBILE吃到飽232元、輕量40元 中華線
# 4    0             [情報] PChome明天搶拉麵道3入$9拿鐵$18
# 5   10                 [情報] PChome Line導購4%回饋
# 6   56                     [情報] line 貼圖表情貼 1折
# 7    6            [情報] Line禮物一點送好友好運最高可拿5200點
# 8    9                       [情報] 麥當勞轉蜜系列買5送5
# 9   15                [情報] apple line導購限定商品7%
#
#                                                   連結    日期  \
# 0  https://www.ptt.cc/bbs/Lifeismoney/M.174437791...  4/11
# 1  https://www.ptt.cc/bbs/Lifeismoney/M.174438968...  4/12
# 2  https://www.ptt.cc/bbs/Lifeismoney/M.174439910...  4/12
# 3  https://www.ptt.cc/bbs/Lifeismoney/M.174440366...  4/12
# 4  https://www.ptt.cc/bbs/Lifeismoney/M.174445710...  4/12
# 5  https://www.ptt.cc/bbs/Lifeismoney/M.174429706...  4/10
# 6  https://www.ptt.cc/bbs/Lifeismoney/M.174434323...  4/11
# 7  https://www.ptt.cc/bbs/Lifeismoney/M.174434904...  4/11
# 8  https://www.ptt.cc/bbs/Lifeismoney/M.174417955...  4/09
# 9  https://www.ptt.cc/bbs/Lifeismoney/M.174421936...  4/10
#
#                                                   內文
# 0  久違的超過10元的紅包\n\n* 不適用無回饋(0%)商品\n* 限訂單金額滿199元\n*...
# 1  line禮物推播，9元折扣券\n折完1元可買麥香，16元可買無糖麥茶、原萃，還有飲冰室、礦泉...
# 2  ※ 引述《danny0830 (丹尼)》之銘言：\n:\nhttps://www.linem...
# 3  : 去年有申辦line mobile的\n: 合約應該都到期或快到期了吧！\n: 我當初也有...
# 4  明天PChome的搶購品\n9元的拉麵道3入包裝\nhttps://reurl.cc/M38...
# 5  PChome今晚22:00~24:00有line導購4%回饋\n很久沒用line導購了\n剛...
# 6  有幾個還不錯\n六元就是買！\nhttps://i.imgur.com/Xccqiqk.jp...
# 7  LINE禮物1點送禮活動又來了\nhttps://giftshop-tw.line.me/v...
# 8  https://i.imgur.com/hFcJUy9.png\n麥當勞LINE官方購買\n...
# 9  https://i.imgur.com/NFsnlTB.jpeg\n雖然不是全品項，但也是蠻...

# %%
# !file static.csv

!(echo -ne '\xEF\xBB\xBF'; cat static.csv) > mac_format.csv
# Out:
# static.csv: CSV text
